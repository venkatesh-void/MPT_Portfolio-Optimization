# %% [markdown]
# # Portfolio Optimization

# %% [markdown]
# “Modern Portfolio Theory (MPT), a hypothesis put forth by Harry Markowitz in his paper “Portfolio Selection,” (published in 1952 by the Journal of Finance) is an investment theory based on the idea that risk-averse investors can construct portfolios to optimize or maximize expected return based on a given level of market risk, emphasizing that risk is an inherent part of higher reward. It is one of the most important and influential economic theories dealing with finance and investment.

# %% [markdown]
# PROJECT SUBMITTED BY: GROUP NO. 16
#
# 1. Vishesh Mehta	            2020A7PS2194H
# 2. Venkatesh Ravindran	        2020A1PS2504H
# 3. Anshul Avinashe	            2020A1PS2536H
# 4. Rohan Sanklecha	            2020A1PS2457H
# 5. Chaitanya Dandwate	        2020A1PS2488H
# 6. Nityan Bhalve	            2020A1PS2471H
# 7. Simratjit Singh	            2020A4PS2179H
# 8. Vaibhav Verma	            2020A4PS2274H
# 9. Vipul Singh	                2020A4PS2241H
# 10. Shreyaan Sharma	            2020A3PS1139H
# 11. Sahil Luthra	            2020A4PS0847H

# %% [markdown]
# Since we are a group of 11, we have choosen 22 assets for the portfolio optimization which are:
#
# 1. HDFC Bank (Large Cap Banking Sector)
#
# 2. Bajaj Finance (Large Cap NBFC Sector)
#
# 3. Tata Motors (Large Cap Automobile Sector)
#
# 4. TCS (Large Cap IT Sector)
#
# 5. Astral (Large Cap Plastic Pipe Sector)
#
# 6. Nifty BEES (ETF NIFTY 50)
#
# 7. Sun Pharma (Large Cap Pharma Sector)
#
# 8. NESTLE (Large Cap FMCG Sector)
#
# 9. Asian Paint (Large Cap Paint Sector)
#
# 10. Jubilant FoodWorks (Large Cap QSR Secto)r
#
# 11. Eicher Motors (Large Cap Automobile Sector)
#
# 12. Bharti Airtel (Large Cap Telecom Sector)
#
# 13. Titan Company (Large Cap Retail Sector)
#
# 14. Avenue Supermart (Large Cap Retail Stores Sector)
#
# 15. PVR (Mid Cap Media and Entertainment Sector)
#
# 16. Alkyl Amine (Mid Cap Chemical Sector)
#
# 17. Varun Beverages (Mid Cap Drinks & Beverage Sector)
#
# 18. APL Apollo Tubes (Mid Cap Steel Tubes Sector)
#
# 19. Page Industries (Mid Cap Innerwear Sector)
#
# 20. KEI Industries (Small Cap Cable and Wiring Sector)
#
# 21. CDSL (Small Cap Broking & Depository Sector)
#
# 22. GOLD BEES (GOLD ETF)

# %% [markdown]
# "Reason To Choose these Stocks in our Portfolio"
#
# 1. HDFC BANK: In the last five years, HDFC Bank has given a good return on investment; along with the good returns, it has a considerably higher brand value, and it also helps in diversifying the portfolio as this stock takes into consideration the effects on the banking sector.
#
# 2. BAJAJ FINANCE: It will help in including the non-banking financial sector, and this stock will help in capturing the systematic risk of financial firms.
#
# 3. TATA MOTORS: Automobile Industry especially the EV has huge growth potential so in order to earn returns as well as diversify we included it.
#
# 4. TCS: It is a large capitalization company, it relatively takes into account the large market size of the IT sector.
#
# 5. ASTRAL: It is in the business of  manufacturing plumbing & drainage systems. Largest company in this sector by market cap and market share	This company has been a 100 bagger in last 15 years. This stock diverfises our portfolio in the Theme of Housing & Infrastructure. The Beta of the stock is quite low as compared with the peers. So we included it in our portfolio.
#
# 6. NIFTY BEES:	NIFTY BEE is an ETF which tracks NIFTY 50 INDEX. We chose this ETF because we want our portfolio to consist of index fund inorder to diversify our portfolio as NIFTY 50 consists of most valued companies among all the major sectors. This provide our portfolio a good sectorial diversification.
#
# 7. SUN PHARMA	One of the largest Pharma Company in India	"We are considering this stock as it has a higher market capitalization and relatively less volatility, and it also helps in diversifying our portfolio.
#
# 8. NESTLE: Nestle is a large, capitalized, fast, moving consumer goods company. They sell a wide range of products, which makes it an ideal choice for taking it into consideration due to its involvement in a lot of sectors.
#
# 9. ASIAN PAINTS: Largest Paint Company in India by Market Share. This company diversifies our portfolio as it belong to the Housing Theme of stocks. it is a leading company, it has a higher return on investment, which is why we are considering it in our portfolio.
#
# 10. JUBLIANT FOODWORKS: Jubilant FoodWorks is an Indian food service company which holds the master franchise for Domino's Pizza , Popeyes and Donuts in serveral countries including India. QSR Industry is one of the fastest growing Industry and Jubiliant is the largest player in the Indian Space. This company has high return to risk ratio when compared to the peers. Thus, this stock represents QSR sector in our portfolio and provides better diversification.
#
# 11. EICHER MOTORS: Eicher motors is an indian motorcycle manufacturing company, it is the parent company of Royal Enfield. This company is working in the domain of Luxury two wheeler automobile segment. In order to invest in this niche segment to diversify our portfolio  and the stock price volatility is also lower as compared to peers.
#
# 12. BHARTI AIRTEL: It is the second largest Telecom Company in India by Market Share. We included this stock to give our portflio an exposure to the fast growing 5G Market in India. This also diversifies our portfolio.
#
# 13. TITAN: Titan Company Limited is an Indian products company that mainly manufactures fashion accessories such as jewellery, watches and eyewear.	To diversify our portfolio and give it the exposure of fast growing comsumer market in India.
#
# 14. AVENUE (DMART): Avenue Supermarts Pvt Ltd.is one of the leading Retial Store chain selling Food, Garments, Toys & Games, Stationery, Footwear, Beauty and various Home Utility Products. We added the stock to diversify the portfolio as well as to give the portfolio an exposure of Retial market.
#
# 15. PVR: PVR Ltd is engaged in the business of film exhibition.The company operates other business such as providing content, film distribution and entertainment park through its subsidiaries. The reason to invest in this stock is to diversify our portfolio in the Entertainment and Leisure Sector.
#
# 16. ALKYL AMINES: It is a global supplier of amines and amine-based chemicals to the pharmaceutical, agrochemical, rubber chemical and water treatment industries, among others.Their product range includes Aliphatic Amines,Amine Derivatives and Fine Chemicals	We invested to give our portfolio an exposure of Chemical industry. We chose alkyl over other chemical players as it has diverse portfolio of chemicals. Thus it futher supplements our diversification and reduces the risk in the chemical sector itself.
#
# 17. VARUN BEVERAGES: Varun Beverages is the bottler of the Pepsi in India and some of other countires in Africa. It has the exclusive rights to sell the pepsi in these countries. As soft drink has the largest market share in the beverages & Alcohol Sector. We included this stock to diversify our portfolio by investing in this deeply moated stock
#
# 18. APL APOLLO: This company sells steel pipes. This company has the highest market share in the steel tube industry. We wanted to invest in the Steel but steel being a cyclical industry in nature we choose APL Apollo over Tata Steels as depite operating in a commodity business it has less volatile margin as well as stock price. Thus having a low risk than the industry peers.
#
# 19. PAGE INDUSTRIES: Page Industries is the Master franchise of Jockey Internationals in India, Bangladesh, Sri Lanks and some of other countires. It has the exclusive rights to sell Jockey in these countries. The reason to choose this stock was to diversify into this secotr of essential items.
#
# 20. KEI INDUSTRIES: It is one of the fastest growing wires and cables company in India.	The reason to choose this was different asset classes to diversify.
#
# 21. CDSL: Central Depository Services Ltd., the first and only listed Indian central securities depository. The CDSL facilitates holding and transacting in securities in the electronic form and facilitates settlement of trades on stock exchanges. We chose this stock as it belong to a niche sector with only two players operating in this sector. It provides a better diversification to our portfolio. This sector is a duopoly and CDSL being the only listed company. As more people are investing and trading in the market the business of these companies are growing very fast.
#
# 22. GOLD BEES: Gold BEES is an ETF which tracks gold. To diversify our portfolio in different asset classes other than equity we choose gold ETF. Also gold is considered as an international currency and it is highly liquid.

# %%
#Importing libraries
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import pandas_datareader.data as web
import scipy as s

# %% [markdown]
# Note: If you are using Google Colab run the below cell to update the pandas datareader version.After updating it then press restart runtime and then continue with the analysis.

# %%
# !pip install --upgrade pandas-datareader
#upgrade pandas datareader
# Out:
# Requirement already satisfied: pandas-datareader in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (0.10.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from pandas-datareader) (2.28.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from pandas-datareader) (1.4.2)
# Requirement already satisfied: lxml in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from pandas-datareader) (4.9.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from pandas>=0.23->pandas-datareader) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2022.9.24)
# Requirement already satisfied: six>=1.5 in c:\users\dell\onedrive\desktop\anshul\bits-general\python\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas-datareader) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the 'C:\Users\DELL\OneDrive\Desktop\ANSHUL\BITS-GENERAL\Python\python.exe -m pip install --upgrade pip' command.

# %%
start = "2017-11-01"
end = "2022-09-01"           
tickers = ['HDFC.NS','NIFTYBEES.NS','SUNPHARMA.NS','TATAMOTORS.NS','ASIANPAINT.NS','NESTLEIND.NS','TCS.NS','PVR.NS','BAJFINANCE.NS','APLAPOLLO.NS','PAGEIND.NS','DMART.NS','ALKYLAMINE.NS','VBL.NS','TITAN.NS','BHARTIARTL.NS','EICHERMOT.NS','CDSL.NS','KEI.NS','JUBLFOOD.NS','ASTRAL.NS','GOLDBEES.NS']
n=22 # number of securities in the portfolio
stocks= pd.DataFrame()

# %%
for ticker in tickers:
    df2 = web.DataReader(ticker,'yahoo',start,end)
    stocks[ticker] = df2['Adj Close']

# %%
stocks.head()
# Out:
#                 HDFC.NS  NIFTYBEES.NS  SUNPHARMA.NS  TATAMOTORS.NS  \
# Date
# 2017-11-01  1634.073120    107.460999    526.628540     437.750000
# 2017-11-02  1641.478271    107.432999    540.785217     434.899994
# 2017-11-03  1654.565308    107.666000    529.076050     447.700012
# 2017-11-06  1667.512573    107.668999    519.430176     462.899994
# 2017-11-07  1643.713989    106.862000    506.377289     451.850006
#
#             ASIANPAINT.NS  NESTLEIND.NS       TCS.NS       PVR.NS  \
# Date
# 2017-11-01    1138.203369   6738.259766  1188.708984  1369.103882
# 2017-11-02    1140.574585   6710.774902  1199.349731  1355.387939
# 2017-11-03    1134.815430   6826.429688  1196.586792  1356.332275
# 2017-11-06    1125.039795   6993.096680  1217.343750  1394.994995
# 2017-11-07    1104.810547   7086.145508  1237.666626  1336.305176
#
#             BAJFINANCE.NS  APLAPOLLO.NS  ...  ALKYLAMINE.NS      VBL.NS  \
# Date                                     ...
# 2017-11-01    1786.960938    182.963898  ...     239.087219  147.270309
# 2017-11-02    1790.373169    180.604889  ...     238.740967  144.530243
# 2017-11-03    1816.829956    181.767303  ...     223.930267  146.448273
# 2017-11-06    1802.043701    184.673355  ...     221.314346  147.847122
# 2017-11-07    1782.807007    184.502426  ...     217.313568  148.323029
#
#               TITAN.NS  BHARTIARTL.NS  EICHERMOT.NS     CDSL.NS      KEI.NS  \
# Date
# 2017-11-01  620.449707     480.908508   2766.761963  347.470367  324.150360
# 2017-11-02  637.677673     484.565979   2785.601074  349.020905  330.741608
# 2017-11-03  642.155029     482.826508   2794.072266  344.980072  332.463165
# 2017-11-06  762.799316     475.065552   2780.944824  338.636749  328.380524
# 2017-11-07  733.696716     458.830078   2787.341064  336.193420  333.643646
#
#             JUBLFOOD.NS   ASTRAL.NS  GOLDBEES.NS
# Date
# 2017-11-01   160.528564  446.942963    26.335501
# 2017-11-02   159.664963  453.212738    26.279499
# 2017-11-03   159.028381  452.048370    26.271000
# 2017-11-06   159.457703  460.288544    26.150499
# 2017-11-07   157.844025  457.332855    26.390499
#
# [5 rows x 22 columns]

# %%
stock_normed = stocks/stocks.iloc[0]
stock_normed.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %% [markdown]
# Log returns are used instead of arithmetic returns, for many of the use cases they are almost the same,but most technical analyses require detrending/normalizing the time series and using log returns is a nice way to do that.
# Log returns are convenient to work with in many of the algorithms we will encounter.

# %%
log_ret = np.log(stocks/stocks.shift(1))
log_ret.head()
# Out:
#              HDFC.NS  NIFTYBEES.NS  SUNPHARMA.NS  TATAMOTORS.NS  \
# Date
# 2017-11-01       NaN           NaN           NaN            NaN
# 2017-11-02  0.004521     -0.000261      0.026527      -0.006532
# 2017-11-03  0.007941      0.002166     -0.021890       0.029007
# 2017-11-06  0.007795      0.000028     -0.018400       0.033388
# 2017-11-07 -0.014375     -0.007523     -0.025450      -0.024161
#
#             ASIANPAINT.NS  NESTLEIND.NS    TCS.NS    PVR.NS  BAJFINANCE.NS  \
# Date
# 2017-11-01            NaN           NaN       NaN       NaN            NaN
# 2017-11-02       0.002081     -0.004087  0.008912 -0.010069       0.001908
# 2017-11-03      -0.005062      0.017087 -0.002306  0.000696       0.014669
# 2017-11-06      -0.008652      0.024122  0.017198  0.028107      -0.008172
# 2017-11-07      -0.018145      0.013218  0.016557 -0.042982      -0.010732
#
#             APLAPOLLO.NS  ...  ALKYLAMINE.NS    VBL.NS  TITAN.NS  \
# Date                      ...
# 2017-11-01           NaN  ...            NaN       NaN       NaN
# 2017-11-02     -0.012977  ...      -0.001449 -0.018781  0.027388
# 2017-11-03      0.006416  ...      -0.064044  0.013183  0.006997
# 2017-11-06      0.015861  ...      -0.011751  0.009507  0.172165
# 2017-11-07     -0.000926  ...      -0.018243  0.003214 -0.038899
#
#             BHARTIARTL.NS  EICHERMOT.NS   CDSL.NS    KEI.NS  JUBLFOOD.NS  \
# Date
# 2017-11-01            NaN           NaN       NaN       NaN          NaN
# 2017-11-02       0.007577      0.006786  0.004452  0.020130    -0.005394
# 2017-11-03      -0.003596      0.003036 -0.011645  0.005192    -0.003995
# 2017-11-06      -0.016205     -0.004709 -0.018559 -0.012356     0.002696
# 2017-11-07      -0.034773      0.002297 -0.007241  0.015900    -0.010171
#
#             ASTRAL.NS  GOLDBEES.NS
# Date
# 2017-11-01        NaN          NaN
# 2017-11-02   0.013931    -0.002129
# 2017-11-03  -0.002572    -0.000323
# 2017-11-06   0.018064    -0.004597
# 2017-11-07  -0.006442     0.009136
#
# [5 rows x 22 columns]

# %%
log_ret.hist(bins=100,figsize=(12,6));
plt.tight_layout()

# %%
log_ret.describe().transpose()
# Out:
#                 count      mean       std       min       25%       50%  \
# HDFC.NS        1194.0  0.000323  0.020150 -0.142700 -0.009895  0.000465
# NIFTYBEES.NS   1194.0  0.000485  0.094716 -2.295293 -0.004576  0.001000
# SUNPHARMA.NS   1194.0  0.000422  0.020250 -0.118296 -0.010710  0.000077
# TATAMOTORS.NS  1194.0  0.000054  0.031249 -0.193375 -0.014744  0.000178
# ASIANPAINT.NS  1194.0  0.000928  0.017310 -0.151148 -0.007873  0.000354
# NESTLEIND.NS   1194.0  0.000900  0.015350 -0.088714 -0.008217  0.000363
# TCS.NS         1194.0  0.000809  0.016577 -0.098830 -0.007408  0.000787
# PVR.NS         1194.0  0.000254  0.025686 -0.142071 -0.011442  0.000908
# BAJFINANCE.NS  1194.0  0.001165  0.026307 -0.264367 -0.010210  0.001179
# APLAPOLLO.NS   1194.0  0.001443  0.026757 -0.199830 -0.013405 -0.000446
# PAGEIND.NS     1194.0  0.000818  0.022082 -0.108279 -0.012379 -0.000719
# DMART.NS       1194.0  0.001153  0.021428 -0.117513 -0.009932  0.000465
# ALKYLAMINE.NS  1194.0  0.002124  0.028206 -0.136879 -0.012147 -0.000439
# VBL.NS         1194.0  0.001639  0.023220 -0.095968 -0.011009  0.000435
# TITAN.NS       1194.0  0.001207  0.020803 -0.130746 -0.008708  0.001343
# BHARTIARTL.NS  1194.0  0.000355  0.021508 -0.127298 -0.011771 -0.000656
# EICHERMOT.NS   1194.0  0.000175  0.021982 -0.134461 -0.012092  0.000106
# CDSL.NS        1194.0  0.001071  0.023137 -0.127252 -0.011122 -0.000922
# KEI.NS         1194.0  0.001250  0.028962 -0.158211 -0.014001 -0.000158
# JUBLFOOD.NS    1194.0  0.001130  0.024102 -0.135636 -0.011493  0.000518
# ASTRAL.NS      1194.0  0.001328  0.024165 -0.212326 -0.010950  0.000883
# GOLDBEES.NS    1194.0  0.000417  0.188777 -4.606540 -0.003789  0.000473
#
#                     75%       max
# HDFC.NS        0.010525  0.097020
# NIFTYBEES.NS   0.006284  2.299434
# SUNPHARMA.NS   0.010493  0.104469
# TATAMOTORS.NS  0.013908  0.186037
# ASIANPAINT.NS  0.009704  0.084826
# NESTLEIND.NS   0.008613  0.120482
# TCS.NS         0.009308  0.093901
# PVR.NS         0.012527  0.150020
# BAJFINANCE.NS  0.013389  0.104049
# APLAPOLLO.NS   0.015609  0.124935
# PAGEIND.NS     0.012641  0.145081
# DMART.NS       0.011934  0.097402
# ALKYLAMINE.NS  0.012281  0.182317
# VBL.NS         0.014050  0.113953
# TITAN.NS       0.011250  0.172165
# BHARTIARTL.NS  0.011506  0.106976
# EICHERMOT.NS   0.011205  0.125576
# CDSL.NS        0.010874  0.167167
# KEI.NS         0.014321  0.175148
# JUBLFOOD.NS    0.013574  0.180902
# ASTRAL.NS      0.012587  0.135902
# GOLDBEES.NS    0.004550  4.605170

# %%
log_ret.mean() * 252
# Out:
# HDFC.NS          0.081497
# NIFTYBEES.NS     0.122292
# SUNPHARMA.NS     0.106398
# TATAMOTORS.NS    0.013606
# ASIANPAINT.NS    0.233833
# NESTLEIND.NS     0.226776
# TCS.NS           0.203905
# PVR.NS           0.064086
# BAJFINANCE.NS    0.293570
# APLAPOLLO.NS     0.363589
# PAGEIND.NS       0.206048
# DMART.NS         0.290682
# ALKYLAMINE.NS    0.535205
# VBL.NS           0.412997
# TITAN.NS         0.304183
# BHARTIARTL.NS    0.089543
# EICHERMOT.NS     0.044217
# CDSL.NS          0.269960
# KEI.NS           0.314995
# JUBLFOOD.NS      0.284677
# ASTRAL.NS        0.334536
# GOLDBEES.NS      0.105188
# dtype: float64

# %%
log_ret.cov()*252 # multiply by days
# Out:
#                 HDFC.NS  NIFTYBEES.NS  SUNPHARMA.NS  TATAMOTORS.NS  \
# HDFC.NS        0.102320      0.052041      0.022174       0.062874
# NIFTYBEES.NS   0.052041      2.260705      0.027346       0.039789
# SUNPHARMA.NS   0.022174      0.027346      0.103339       0.045041
# TATAMOTORS.NS  0.062874      0.039789      0.045041       0.246083
# ASIANPAINT.NS  0.031699      0.020549      0.016411       0.037622
# NESTLEIND.NS   0.018269      0.003550      0.014452       0.021106
# TCS.NS         0.024685      0.010435      0.017076       0.034039
# PVR.NS         0.040991      0.027372      0.024009       0.070670
# BAJFINANCE.NS  0.077278      0.057914      0.031617       0.084729
# APLAPOLLO.NS   0.042041      0.058778      0.021964       0.068999
# PAGEIND.NS     0.029313      0.029232      0.028547       0.050999
# DMART.NS       0.037502      0.021832      0.020604       0.051606
# ALKYLAMINE.NS  0.035680      0.010904      0.030469       0.061588
# VBL.NS         0.023137      0.012971      0.012180       0.032053
# TITAN.NS       0.041949      0.034862      0.022605       0.065849
# BHARTIARTL.NS  0.036511      0.016480      0.026348       0.050980
# EICHERMOT.NS   0.047477      0.018556      0.023475       0.069550
# CDSL.NS        0.031795      0.024787      0.024509       0.061821
# KEI.NS         0.036654      0.052706      0.022043       0.058253
# JUBLFOOD.NS    0.041330      0.023381      0.027548       0.061932
# ASTRAL.NS      0.038783      0.024330      0.024126       0.050961
# GOLDBEES.NS    0.017187      4.468454      0.009987      -0.030155
#
#                ASIANPAINT.NS  NESTLEIND.NS    TCS.NS    PVR.NS  BAJFINANCE.NS  \
# HDFC.NS             0.031699      0.018269  0.024685  0.040991       0.077278
# NIFTYBEES.NS        0.020549      0.003550  0.010435  0.027372       0.057914
# SUNPHARMA.NS        0.016411      0.014452  0.017076  0.024009       0.031617
# TATAMOTORS.NS       0.037622      0.021106  0.034039  0.070670       0.084729
# ASIANPAINT.NS       0.075505      0.029658  0.017559  0.028581       0.043603
# NESTLEIND.NS        0.029658      0.059377  0.015122  0.016877       0.026644
# TCS.NS              0.017559      0.015122  0.069245  0.018159       0.024027
# PVR.NS              0.028581      0.016877  0.018159  0.166264       0.066670
# BAJFINANCE.NS       0.043603      0.026644  0.024027  0.066670       0.174403
# APLAPOLLO.NS        0.033537      0.020749  0.024852  0.040199       0.056933
# PAGEIND.NS          0.028618      0.019807  0.016172  0.032701       0.049542
# DMART.NS            0.026695      0.020047  0.017267  0.034499       0.047435
# ALKYLAMINE.NS       0.032840      0.023359  0.024795  0.053963       0.058887
# VBL.NS              0.014548      0.007947  0.006313  0.020148       0.037443
# TITAN.NS            0.035293      0.028162  0.021264  0.039498       0.054379
# BHARTIARTL.NS       0.024694      0.015093  0.016670  0.034383       0.047673
# EICHERMOT.NS        0.036931      0.021288  0.016866  0.045616       0.066883
# CDSL.NS             0.026795      0.015957  0.013446  0.037982       0.051638
# KEI.NS              0.030168      0.020897  0.017636  0.040285       0.061021
# JUBLFOOD.NS         0.037824      0.027679  0.029274  0.046822       0.060893
# ASTRAL.NS           0.029480      0.020038  0.020641  0.032965       0.056623
# GOLDBEES.NS        -0.009275     -0.026257 -0.022828 -0.013821       0.008398
#
#                APLAPOLLO.NS  ...  ALKYLAMINE.NS    VBL.NS  TITAN.NS  \
# HDFC.NS            0.042041  ...       0.035680  0.023137  0.041949
# NIFTYBEES.NS       0.058778  ...       0.010904  0.012971  0.034862
# SUNPHARMA.NS       0.021964  ...       0.030469  0.012180  0.022605
# TATAMOTORS.NS      0.068999  ...       0.061588  0.032053  0.065849
# ASIANPAINT.NS      0.033537  ...       0.032840  0.014548  0.035293
# NESTLEIND.NS       0.020749  ...       0.023359  0.007947  0.028162
# TCS.NS             0.024852  ...       0.024795  0.006313  0.021264
# PVR.NS             0.040199  ...       0.053963  0.020148  0.039498
# BAJFINANCE.NS      0.056933  ...       0.058887  0.037443  0.054379
# APLAPOLLO.NS       0.180421  ...       0.043615  0.036439  0.042892
# PAGEIND.NS         0.035370  ...       0.038363  0.020244  0.036857
# DMART.NS           0.037536  ...       0.035872  0.016211  0.036904
# ALKYLAMINE.NS      0.043615  ...       0.200482  0.024618  0.035078
# VBL.NS             0.036439  ...       0.024618  0.135871  0.023964
# TITAN.NS           0.042892  ...       0.035078  0.023964  0.109053
# BHARTIARTL.NS      0.025497  ...       0.024297  0.013320  0.028467
# EICHERMOT.NS       0.040867  ...       0.041100  0.018145  0.043151
# CDSL.NS            0.045183  ...       0.047317  0.020286  0.033634
# KEI.NS             0.055155  ...       0.049477  0.029551  0.040173
# JUBLFOOD.NS        0.040483  ...       0.053478  0.024853  0.052507
# ASTRAL.NS          0.048013  ...       0.036224  0.024431  0.038349
# GOLDBEES.NS        0.049516  ...      -0.042647 -0.009350  0.005216
#
#                BHARTIARTL.NS  EICHERMOT.NS   CDSL.NS    KEI.NS  JUBLFOOD.NS  \
# HDFC.NS             0.036511      0.047477  0.031795  0.036654     0.041330
# NIFTYBEES.NS        0.016480      0.018556  0.024787  0.052706     0.023381
# SUNPHARMA.NS        0.026348      0.023475  0.024509  0.022043     0.027548
# TATAMOTORS.NS       0.050980      0.069550  0.061821  0.058253     0.061932
# ASIANPAINT.NS       0.024694      0.036931  0.026795  0.030168     0.037824
# NESTLEIND.NS        0.015093      0.021288  0.015957  0.020897     0.027679
# TCS.NS              0.016670      0.016866  0.013446  0.017636     0.029274
# PVR.NS              0.034383      0.045616  0.037982  0.040285     0.046822
# BAJFINANCE.NS       0.047673      0.066883  0.051638  0.061021     0.060893
# APLAPOLLO.NS        0.025497      0.040867  0.045183  0.055155     0.040483
# PAGEIND.NS          0.018819      0.042791  0.031035  0.041664     0.041152
# DMART.NS            0.025278      0.036516  0.026604  0.034543     0.037095
# ALKYLAMINE.NS       0.024297      0.041100  0.047317  0.049477     0.053478
# VBL.NS              0.013320      0.018145  0.020286  0.029551     0.024853
# TITAN.NS            0.028467      0.043151  0.033634  0.040173     0.052507
# BHARTIARTL.NS       0.116575      0.032010  0.025508  0.023686     0.027227
# EICHERMOT.NS        0.032010      0.121768  0.034264  0.038221     0.049540
# CDSL.NS             0.025508      0.034264  0.134902  0.038634     0.035782
# KEI.NS              0.023686      0.038221  0.038634  0.211380     0.039209
# JUBLFOOD.NS         0.027227      0.049540  0.035782  0.039209     0.146391
# ASTRAL.NS           0.021791      0.039177  0.037448  0.046250     0.035842
# GOLDBEES.NS        -0.023352     -0.037494 -0.006423  0.042973    -0.017819
#
#                ASTRAL.NS  GOLDBEES.NS
# HDFC.NS         0.038783     0.017187
# NIFTYBEES.NS    0.024330     4.468454
# SUNPHARMA.NS    0.024126     0.009987
# TATAMOTORS.NS   0.050961    -0.030155
# ASIANPAINT.NS   0.029480    -0.009275
# NESTLEIND.NS    0.020038    -0.026257
# TCS.NS          0.020641    -0.022828
# PVR.NS          0.032965    -0.013821
# BAJFINANCE.NS   0.056623     0.008398
# APLAPOLLO.NS    0.048013     0.049516
# PAGEIND.NS      0.032562     0.006137
# DMART.NS        0.036449    -0.011576
# ALKYLAMINE.NS   0.036224    -0.042647
# VBL.NS          0.024431    -0.009350
# TITAN.NS        0.038349     0.005216
# BHARTIARTL.NS   0.021791    -0.023352
# EICHERMOT.NS    0.039177    -0.037494
# CDSL.NS         0.037448    -0.006423
# KEI.NS          0.046250     0.042973
# JUBLFOOD.NS     0.035842    -0.017819
# ASTRAL.NS       0.147152    -0.012090
# GOLDBEES.NS    -0.012090     8.980497
#
# [22 rows x 22 columns]

# %%
corr = log_ret.corr()
sns.heatmap(corr,annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot: >

# %%
# Set seed (optional)
np.random.seed(101)
rf = 0.03 # risk free rate of return should be found according to time period of analysis
# Stock Columns
print('Stocks')
print(stocks.columns)
print('\n')

# Creating Random Weights
print('Creating Random Weights')
weights = np.array(np.random.random(n))
print(weights)
print('\n')

# Rebalance Weights to sum to 1
print('Rebalance to sum to 1.0')
weights = weights / np.sum(weights)
print(weights)
print('\n')

# Expected Return
print('Expected Portfolio Return')
exp_ret = np.sum(log_ret.mean() * weights) *252
print(exp_ret)
print('\n')

# Expected Variance
print('Expected Volatility')
exp_vol = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))
print(exp_vol)
print('\n')

# Sharpe Ratio
SR = (exp_ret-rf)/exp_vol
print('Sharpe Ratio')
print(SR)
# Out:
# Stocks
# Index(['HDFC.NS', 'NIFTYBEES.NS', 'SUNPHARMA.NS', 'TATAMOTORS.NS',
#        'ASIANPAINT.NS', 'NESTLEIND.NS', 'TCS.NS', 'PVR.NS', 'BAJFINANCE.NS',
#        'APLAPOLLO.NS', 'PAGEIND.NS', 'DMART.NS', 'ALKYLAMINE.NS', 'VBL.NS',
#        'TITAN.NS', 'BHARTIARTL.NS', 'EICHERMOT.NS', 'CDSL.NS', 'KEI.NS',
#        'JUBLFOOD.NS', 'ASTRAL.NS', 'GOLDBEES.NS'],
#       dtype='object')
#
#
# Creating Random Weights
# [0.51639863 0.57066759 0.02847423 0.17152166 0.68527698 0.83389686
#  0.30696622 0.89361308 0.72154386 0.18993895 0.55422759 0.35213195
#  0.1818924  0.78560176 0.96548322 0.23235366 0.08356143 0.60354842
#  0.72899276 0.27623883 0.68530633 0.51786747]
#
#
# Rebalance to sum to 1.0
# [0.04743911 0.05242454 0.00261579 0.01575689 0.06295317 0.07660618
#  0.02819954 0.08209203 0.06628484 0.0174488  0.05091428 0.0323487
#  0.0167096  0.07216954 0.0886944  0.02134524 0.0076764  0.05544515
#  0.06696913 0.02537676 0.06295587 0.04757405]
#
#
# Expected Portfolio Return
# 0.236902583563943
#
#
# Expected Volatility
# 0.28972296608087256
#
#
# Sharpe Ratio
# 0.7141393944799969

# %% [markdown]
# # **Utility Function**
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# A if a function of age, gender, income, wealth and investment
# horizon.
# Risk neutral implies A=0 and A<0 for risk lovers and A>0 for
# risk averse investors.

# %%
Util=[]   # Empty list to store utility function values
A=4       # Risk Aversion factor
max_util_ret=0
max_util_risk=0

# %% [markdown]
# # **Efficient Frontier**
#
# ### **Case : when short selling is not allowed**
#
#
# The efficient frontier represents that set of portfolios with the maximum
# rate of return for every given level of risk, or the minimum risk for every
# level of return.Efficient frontier is the upward sloping part of the investment
# opportunity set originating from the minimum variance
# portfolio.
#
# ![image.png](data:image/png;base64,...)

# %%
num_ports = 15000

all_weights = np.zeros((num_ports,len(stocks.columns)))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)

for ind in range(num_ports):

    # Create Random Weights
    weights = np.array(np.random.random(n))

    # Rebalance Weights
    weights = weights / np.sum(weights)
    
    # Save Weights
    all_weights[ind,:] = weights

    # Expected Return
    ret_arr[ind] = np.sum((log_ret.mean() * weights) *252)

    # Expected Variance
    vol_arr[ind] = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))

    # Sharpe Ratio
    sharpe_arr[ind] = (ret_arr[ind]-rf)/vol_arr[ind]
    
    Util.append(ret_arr[ind]-0.5*A*vol_arr[ind]**2)
    if Util[ind]>=max(Util):
        max_util_ret=ret_arr[ind]
        max_util_risk=vol_arr[ind]

# %%
# To find Minimum Variance and corresponding returns
min_vol_port = vol_arr.min()  
ind=np.argmin(vol_arr)  #index of minimum volitality

# %%
print("Maximum Utility function:",max(Util))
print("Return corresponding to Maximum Utility:",max_util_ret)
print("Risk corresponding to Maximum Utility:",max_util_ret)
# Out:
# Maximum Utility function: 0.19306777959197838
# Return corresponding to Maximum Utility: 0.2811438593542339
# Risk corresponding to Maximum Utility: 0.2811438593542339

# %% [markdown]
# ## Case where short selling is allowed:

# %%
num_ports = 15000

all_weights = np.zeros((num_ports,len(stocks.columns)))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)
vcm=pd.DataFrame()
for ind in range(num_ports):

    # Create Random Weights
    weights = np.array(np.random.uniform(-1,1,n))

    # Rebalance Weights
    weights = s.special.softmax (weights)
    
    # Save Weights
    all_weights[ind,:] = weights

    # Expected Return 
    ret_arr[ind] = np.sum((log_ret.mean() * weights) *252)

    # Expected Variance 
    vol_arr[ind] = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))


    # Sharpe Ratio
    sharpe_arr[ind] = (ret_arr[ind]-rf)/vol_arr[ind]
    
    Util.append(ret_arr[ind]-0.5*A*vol_arr[ind]**2)
    if Util[ind]>=max(Util):
        max_util_ret=ret_arr[ind]
        max_util_risk=vol_arr[ind]

# %%
# To find Minimum Variance and corresponding returns
min_vol_port = vol_arr.min()  
ind=np.argmin(vol_arr)  #index of minimum volitality

# %%
print("Maximum Utility function:",max(Util))
print("Return corresponding to Maximum Utility:",max_util_ret)
print("Risk corresponding to Maximum Utility:",max_util_ret)
# Out:
# Maximum Utility function: 0.19306777959197838
# Return corresponding to Maximum Utility: 0.20867880905424024
# Risk corresponding to Maximum Utility: 0.20867880905424024

# %% [markdown]
# # **Generating Utility Curve**

# %%
risk=np.linspace(vol_arr.min(),vol_arr.max(),50)
print(risk)
# Out:
# [0.19553993 0.20272226 0.2099046  0.21708694 0.22426927 0.23145161
#  0.23863394 0.24581628 0.25299861 0.26018095 0.26736328 0.27454562
#  0.28172795 0.28891029 0.29609262 0.30327496 0.31045729 0.31763963
#  0.32482197 0.3320043  0.33918664 0.34636897 0.35355131 0.36073364
#  0.36791598 0.37509831 0.38228065 0.38946298 0.39664532 0.40382765
#  0.41100999 0.41819233 0.42537466 0.432557   0.43973933 0.44692167
#  0.454104   0.46128634 0.46846867 0.47565101 0.48283334 0.49001568
#  0.49719801 0.50438035 0.51156268 0.51874502 0.52592736 0.53310969
#  0.54029203 0.54747436]

# %%
exp_ret=max(Util)+0.5*4*risk**2
exp_ret
# Out:
# array([0.26953951, 0.27526041, 0.28118766, 0.28732125, 0.29366119,
#        0.30020747, 0.3069601 , 0.31391906, 0.32108438, 0.32845603,
#        0.33603403, 0.34381837, 0.35180906, 0.36000609, 0.36840946,
#        0.37701918, 0.38583524, 0.39485765, 0.4040864 , 0.41352149,
#        0.42316293, 0.43301071, 0.44306483, 0.4533253 , 0.46379211,
#        0.47446527, 0.48534477, 0.49643061, 0.5077228 , 0.51922133,
#        0.5309262 , 0.54283742, 0.55495498, 0.56727889, 0.57980914,
#        0.59254573, 0.60548867, 0.61863795, 0.63199357, 0.64555554,
#        0.65932385, 0.67329851, 0.68747951, 0.70186685, 0.71646054,
#        0.73126057, 0.74626695, 0.76147966, 0.77689873, 0.79252413])

# %% [markdown]
# **Plotting the data**

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr,ret_arr,marker = 'o' , s = 10 ,alpha = 0.5 , color = 'green' )
plt.plot(risk,exp_ret)
plt.scatter(max_util_risk,max_util_ret,color='r',s=200,marker='*')
plt.scatter(min_vol_port,ret_arr[ind],color='b',s=200)
plt.title("Efficient Frontier")
plt.xlabel('Volatility')
plt.ylabel('Return')
# Out:
# Text(0, 0.5, 'Return')

# %% [markdown]
# The Blue point in the above figure corresponds to minimum volitality point.Red star coressponds to the optimal portfolio satisfied by the Utility curve(indifference curve)

# %% [markdown]
# # **Tangency portfolio for n securities with riskless asset can be found by maximizing the sharpe Ratio**
#
#
# ![image.png](data:image/png;base64,...)

# %%
# Finding the optimal portfolio : Highest SHARPE RATIO
optimal_risky_port_max = sharpe_arr.max()
index_max_sharpe=np.argmax(sharpe_arr)
max_sharpe_exp_ret = ret_arr[index_max_sharpe]
max_sharpe_vol = vol_arr[index_max_sharpe]

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr,ret_arr,marker = 'o' , s = 10 ,alpha = 0.5 , color = 'green' )
plt.scatter(max_sharpe_vol,max_sharpe_exp_ret,color='#d62728',s=200)
plt.scatter(min_vol_port,ret_arr[ind],color='y',s=200)
plt.title("Efficient Frontier")
plt.xlabel('Volatility')
plt.ylabel('Return')
# Out:
# Text(0, 0.5, 'Return')

# %% [markdown]
# The yellow point in the above figure corresponds to minimum volitality point from which the efficient curve starts.Red star coressponds to the optimal tangency portfolio when a riskless asset is also involved
