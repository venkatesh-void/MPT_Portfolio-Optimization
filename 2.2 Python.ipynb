# %% [markdown]
# PROJECT SUBMITTED BY: GROUP NO. 16
#
# 1. Vishesh Mehta	            2020A7PS2194H
# 2. Venkatesh Ravindran	        2020A1PS2504H
# 3. Anshul Avinashe	            2020A1PS2536H
# 4. Rohan Sanklecha	            2020A1PS2457H
# 5. Chaitanya Dandwate	        2020A1PS2488H
# 6. Nityan Bhalve	            2020A1PS2471H
# 7. Simratjit Singh	            2020A4PS2179H
# 8. Vaibhav Verma	            2020A4PS2274H
# 9. Vipul Singh	                2020A4PS2241H
# 10. Shreyaan Sharma	            2020A3PS1139H
# 11. Sahil Luthra	            2020A4PS0847H

# %% [markdown]
# Since we are a group of 11, we have choosen 22 assets for the portfolio optimization which are:
#
# 1. HDFC Bank (Large Cap Banking Sector)
#
# 2. Bajaj Finance (Large Cap NBFC Sector)
#
# 3. Tata Motors (Large Cap Automobile Sector)
#
# 4. TCS (Large Cap IT Sector)
#
# 5. Astral (Large Cap Plastic Pipe Sector)
#
# 6. Nifty BEES (ETF NIFTY 50)
#
# 7. Sun Pharma (Large Cap Pharma Sector)
#
# 8. NESTLE (Large Cap FMCG Sector)
#
# 9. Asian Paint (Large Cap Paint Sector)
#
# 10. Jubilant FoodWorks (Large Cap QSR Secto)r
#
# 11. Eicher Motors (Large Cap Automobile Sector)
#
# 12. Bharti Airtel (Large Cap Telecom Sector)
#
# 13. Titan Company (Large Cap Retail Sector)
#
# 14. Avenue Supermart (Large Cap Retail Stores Sector)
#
# 15. PVR (Mid Cap Media and Entertainment Sector)
#
# 16. Alkyl Amine (Mid Cap Chemical Sector)
#
# 17. Varun Beverages (Mid Cap Drinks & Beverage Sector)
#
# 18. APL Apollo Tubes (Mid Cap Steel Tubes Sector)
#
# 19. Page Industries (Mid Cap Innerwear Sector)
#
# 20. KEI Industries (Small Cap Cable and Wiring Sector)
#
# 21. CDSL (Small Cap Broking & Depository Sector)
#
# 22. GOLD BEES (GOLD ETF)

# %% [markdown]
# "Reason To Choose these Stocks in our Portfolio"
#
# 1. HDFC BANK: In the last five years, HDFC Bank has given a good return on investment; along with the good returns, it has a considerably higher brand value, and it also helps in diversifying the portfolio as this stock takes into consideration the effects on the banking sector.
#
# 2. BAJAJ FINANCE: It will help in including the non-banking financial sector, and this stock will help in capturing the systematic risk of financial firms.
#
# 3. TATA MOTORS: Automobile Industry especially the EV has huge growth potential so in order to earn returns as well as diversify we included it.
#
# 4. TCS: It is a large capitalization company, it relatively takes into account the large market size of the IT sector.
#
# 5. ASTRAL: It is in the business of  manufacturing plumbing & drainage systems. Largest company in this sector by market cap and market share	This company has been a 100 bagger in last 15 years. This stock diverfises our portfolio in the Theme of Housing & Infrastructure. The Beta of the stock is quite low as compared with the peers. So we included it in our portfolio.
#
# 6. NIFTY BEES:	NIFTY BEE is an ETF which tracks NIFTY 50 INDEX. We chose this ETF because we want our portfolio to consist of index fund inorder to diversify our portfolio as NIFTY 50 consists of most valued companies among all the major sectors. This provide our portfolio a good sectorial diversification.
#
# 7. SUN PHARMA	One of the largest Pharma Company in India	"We are considering this stock as it has a higher market capitalization and relatively less volatility, and it also helps in diversifying our portfolio.
#
# 8. NESTLE: Nestle is a large, capitalized, fast, moving consumer goods company. They sell a wide range of products, which makes it an ideal choice for taking it into consideration due to its involvement in a lot of sectors.
#
# 9. ASIAN PAINTS: Largest Paint Company in India by Market Share. This company diversifies our portfolio as it belong to the Housing Theme of stocks. it is a leading company, it has a higher return on investment, which is why we are considering it in our portfolio.
#
# 10. JUBLIANT FOODWORKS: Jubilant FoodWorks is an Indian food service company which holds the master franchise for Domino's Pizza , Popeyes and Donuts in serveral countries including India. QSR Industry is one of the fastest growing Industry and Jubiliant is the largest player in the Indian Space. This company has high return to risk ratio when compared to the peers. Thus, this stock represents QSR sector in our portfolio and provides better diversification.
#
# 11. EICHER MOTORS: Eicher motors is an indian motorcycle manufacturing company, it is the parent company of Royal Enfield. This company is working in the domain of Luxury two wheeler automobile segment. In order to invest in this niche segment to diversify our portfolio  and the stock price volatility is also lower as compared to peers.
#
# 12. BHARTI AIRTEL: It is the second largest Telecom Company in India by Market Share. We included this stock to give our portflio an exposure to the fast growing 5G Market in India. This also diversifies our portfolio.
#
# 13. TITAN: Titan Company Limited is an Indian products company that mainly manufactures fashion accessories such as jewellery, watches and eyewear.	To diversify our portfolio and give it the exposure of fast growing comsumer market in India.
#
# 14. AVENUE (DMART): Avenue Supermarts Pvt Ltd.is one of the leading Retial Store chain selling Food, Garments, Toys & Games, Stationery, Footwear, Beauty and various Home Utility Products. We added the stock to diversify the portfolio as well as to give the portfolio an exposure of Retial market.
#
# 15. PVR: PVR Ltd is engaged in the business of film exhibition.The company operates other business such as providing content, film distribution and entertainment park through its subsidiaries. The reason to invest in this stock is to diversify our portfolio in the Entertainment and Leisure Sector.
#
# 16. ALKYL AMINES: It is a global supplier of amines and amine-based chemicals to the pharmaceutical, agrochemical, rubber chemical and water treatment industries, among others.Their product range includes Aliphatic Amines,Amine Derivatives and Fine Chemicals	We invested to give our portfolio an exposure of Chemical industry. We chose alkyl over other chemical players as it has diverse portfolio of chemicals. Thus it futher supplements our diversification and reduces the risk in the chemical sector itself.
#
# 17. VARUN BEVERAGES: Varun Beverages is the bottler of the Pepsi in India and some of other countires in Africa. It has the exclusive rights to sell the pepsi in these countries. As soft drink has the largest market share in the beverages & Alcohol Sector. We included this stock to diversify our portfolio by investing in this deeply moated stock
#
# 18. APL APOLLO: This company sells steel pipes. This company has the highest market share in the steel tube industry. We wanted to invest in the Steel but steel being a cyclical industry in nature we choose APL Apollo over Tata Steels as depite operating in a commodity business it has less volatile margin as well as stock price. Thus having a low risk than the industry peers.
#
# 19. PAGE INDUSTRIES: Page Industries is the Master franchise of Jockey Internationals in India, Bangladesh, Sri Lanks and some of other countires. It has the exclusive rights to sell Jockey in these countries. The reason to choose this stock was to diversify into this secotr of essential items.
#
# 20. KEI INDUSTRIES: It is one of the fastest growing wires and cables company in India.	The reason to choose this was different asset classes to diversify.
#
# 21. CDSL: Central Depository Services Ltd., the first and only listed Indian central securities depository. The CDSL facilitates holding and transacting in securities in the electronic form and facilitates settlement of trades on stock exchanges. We chose this stock as it belong to a niche sector with only two players operating in this sector. It provides a better diversification to our portfolio. This sector is a duopoly and CDSL being the only listed company. As more people are investing and trading in the market the business of these companies are growing very fast.
#
# 22. GOLD BEES: Gold BEES is an ETF which tracks gold. To diversify our portfolio in different asset classes other than equity we choose gold ETF. Also gold is considered as an international currency and it is highly liquid.

# %%
# !pip install yfinance
from statsmodels.stats.diagnostic import het_white
import warnings
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas_datareader as pdr
import datetime as dt
import seaborn as sns
import yfinance as yf
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols
import scipy.stats as stats

warnings.filterwarnings("ignore")
#%matplotlib notebook
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Extraction And Processing Of Data

# %% [markdown]
# We have scrapped monthly data of the selected stocks and the NSEI market index 2017-11-01 onwards from Yahoo finance

# %%
tickers = ['^NSEI','HDFC.NS','NIFTYBEES.NS','SUNPHARMA.NS','TATAMOTORS.NS','ASIANPAINT.NS','NESTLEIND.NS','TCS.NS','PVR.NS','BAJFINANCE.NS','APLAPOLLO.NS','PAGEIND.NS','DMART.NS','ALKYLAMINE.NS','VBL.NS','TITAN.NS','BHARTIARTL.NS','EICHERMOT.NS','CDSL.NS','KEI.NS','JUBLFOOD.NS','ASTRAL.NS','GOLDBEES.NS']


n=len(tickers)-1

#data = yf.download(tickers, 
#                      start='2017-11-01', end = '2022-10-01',
#)

data = yf.download(tickers, 
                      start='2017-11-01', end = '2022-10-01',
                      progress=False,interval ='1mo'
)

# %% [markdown]
# Acquiring the adjoining closing prices

# %%
data = data['Adj Close']
data.head()
# Out:
#             ALKYLAMINE.NS  APLAPOLLO.NS  ASIANPAINT.NS   ASTRAL.NS  \
# Date
# 2017-11-01     227.027069    193.396393    1109.940796  504.624634
# 2017-12-01     257.552490    193.777344    1121.313599  504.516693
# 2018-01-01     271.036011    209.372330    1092.082886  477.100220
# 2018-02-01     241.145325    200.532074    1081.871460  541.490051
# 2018-03-01     228.527359    194.075287    1084.436279  533.486206
#
#             BAJFINANCE.NS  BHARTIARTL.NS     CDSL.NS     DMART.NS  \
# Date
# 2017-11-01    1708.133789     442.862274  341.784882  1118.099976
# 2017-12-01    1737.458862     472.478607  336.052460  1181.349976
# 2018-01-01    1659.472656     392.371765  313.498627  1179.650024
# 2018-02-01    1622.284546     384.725677  300.154236  1348.150024
# 2018-03-01    1748.190186     357.928223  265.618683  1324.800049
#
#             EICHERMOT.NS  GOLDBEES.NS  ...  NESTLEIND.NS  NIFTYBEES.NS  \
# Date                                   ...
# ...

# %% [markdown]
# Using log returns instead of arithmetic returns, for many of the use cases they are synonymous.
# Log returns have wide use cases in many algorithms.

# %%
log_returns = np.log(data/data.shift())
log_returns.head()
# Out:
#             ALKYLAMINE.NS  APLAPOLLO.NS  ASIANPAINT.NS  ASTRAL.NS  \
# Date
# 2017-11-01            NaN           NaN            NaN        NaN
# 2017-12-01       0.126154      0.001968       0.010194  -0.000214
# 2018-01-01       0.051028      0.077404      -0.026414  -0.055874
# 2018-02-01      -0.116852     -0.043140      -0.009394   0.126598
# 2018-03-01      -0.053744     -0.032728       0.002368  -0.014891
#
#             BAJFINANCE.NS  BHARTIARTL.NS   CDSL.NS  DMART.NS  EICHERMOT.NS  \
# Date
# 2017-11-01            NaN            NaN       NaN       NaN           NaN
# 2017-12-01       0.017022       0.064734 -0.016914  0.055027      0.013164
# 2018-01-01      -0.045924      -0.185783 -0.069472 -0.001440     -0.119492
# 2018-02-01      -0.022665      -0.019679 -0.043499  0.133515      0.018917
# 2018-03-01       0.074746      -0.072198 -0.122235 -0.017472      0.033506
#
#             GOLDBEES.NS  ...  NESTLEIND.NS  NIFTYBEES.NS  PAGEIND.NS  \
# Date                     ...
# ...

# %% [markdown]
# We annualize the monthly returns by multiplying 12

# %%
annual_exp_ret = log_returns.mean() * 12
annual_exp_ret
# Out:
# ALKYLAMINE.NS    0.524820
# APLAPOLLO.NS     0.346955
# ASIANPAINT.NS    0.228082
# ASTRAL.NS        0.307663
# BAJFINANCE.NS    0.301522
# BHARTIARTL.NS    0.122323
# CDSL.NS          0.265250
# DMART.NS         0.282809
# EICHERMOT.NS     0.065243
# GOLDBEES.NS      0.102481
# HDFC.NS          0.079103
# JUBLFOOD.NS      0.262368
# KEI.NS           0.270751
# NESTLEIND.NS     0.206494
# NIFTYBEES.NS     0.117757
# PAGEIND.NS       0.178249
# PVR.NS           0.064745
# SUNPHARMA.NS     0.125094
# TATAMOTORS.NS    0.000230
# TCS.NS           0.188615
# TITAN.NS         0.245174
# VBL.NS           0.406210
# ^NSEI            0.106295
# dtype: float64

# %%
annual_cov_matrix=log_returns.cov()*12 
annual_cov_matrix
# Out:
#                ALKYLAMINE.NS  APLAPOLLO.NS  ASIANPAINT.NS  ASTRAL.NS  \
# ALKYLAMINE.NS       0.219450      0.088883       0.020521   0.052313
# APLAPOLLO.NS        0.088883      0.192796       0.043968   0.068652
# ASIANPAINT.NS       0.020521      0.043968       0.063927   0.035910
# ASTRAL.NS           0.052313      0.068652       0.035910   0.096159
# BAJFINANCE.NS       0.096487      0.104282       0.047041   0.097884
# BHARTIARTL.NS       0.040961      0.027558       0.004206   0.019594
# CDSL.NS             0.077027      0.082708       0.017530   0.054827
# DMART.NS            0.028666      0.033241       0.041763   0.039137
# EICHERMOT.NS        0.053644      0.059226       0.018215   0.036778
# GOLDBEES.NS         0.002875     -0.011733       0.000740  -0.007448
# HDFC.NS             0.044021      0.053940       0.024979   0.036311
# JUBLFOOD.NS         0.073988      0.072014       0.028419   0.053343
# KEI.NS              0.068597      0.109730       0.044203   0.092181
# ...

# %% [markdown]
# # Defining functions and variables for Calculation of Beta

# %% [markdown]
# here we initialize the dataframes for
#
# 1.   alpha of stock
# 2.   beta of stock
# 3.   r-squared
# 4.   statistics of residue
# 5.   white's test statistics

# %%
alpha_df=pd.Series()
beta_df=pd.Series()
rsq_df=pd.Series()
stats_df=pd.DataFrame()
whitetest_df=pd.DataFrame()

# %%
def linear_regression(ticker_a, ticker_b):
    df=log_returns[[ticker_a,ticker_b]]
    df=df.dropna()
    x = df[ticker_b]
    y = df[ticker_a]
    x_sm = sm.add_constant(x)

    model = sm.OLS(y,x_sm)
    results = model.fit()
    #print("r square score of "+ticker_a+": "+str(lin_regr.score(X,Y)))
    
    #Y_pred = lin_regr.predict(X)

    alpha = results.params[0]
    alpha_df[ticker_a]=alpha
    beta = results.params[1]
    beta_df[ticker_a]=beta
    rsq_df[ticker_a]=results.rsquared

    stats_df[ticker_a]=results.resid.describe()

    fig, ax = plt.subplots(nrows=1, ncols=3)
    fig.set_figheight(12)
    fig.set_figwidth(60)

    sns.regplot(x = ticker_b, y = ticker_a, data = log_returns, ax=ax[0])
    #ax1.set_title(ticker_a+ "- Alpha: " + str(round(alpha, 5)) + ", Beta: " + str(round(beta, 3)))
    #ax1.scatter(X, Y)
    #ax1.plot(X, Y_pred, c='r')
    sns.distplot(results.resid, ax=ax[1])
    sm.qqplot(results.resid,line='45',fit=True,dist=stats.norm, ax=ax[2])

    #stats_df.append()


    #Checking for Homoskedasticity of errors (Assumption requirement of linear regression)
    #perform White's test
    white_test = het_white(results.resid,  results.model.exog)
    whitetest_df[ticker_a]=white_test

# %% [markdown]
# # Generating beta of stocks and other statistics of linear regression

# %%
for ticker in tickers:
    if(ticker=="^NSEI"):
      continue

    linear_regression(ticker, "^NSEI")

print("\n------betas------")
print(beta_df)

print("\n------r squared scores------")
print(rsq_df)

print("\n------residue analysis------")
print(stats_df)

whitetest_df.rename(index={0:'Test Statistic', 1:'Test Statistic p-value', 2:'F-Statistic', 3:'F-Test p-value'}, inplace=True)
print("\n------white's test rsults------")
print(whitetest_df)
# Out:
# ------betas------
# HDFC.NS          1.130908
# NIFTYBEES.NS     0.978516
# SUNPHARMA.NS     0.625781
# TATAMOTORS.NS    1.919822
# ASIANPAINT.NS    0.567892
# NESTLEIND.NS     0.286612
# TCS.NS           0.554481
# PVR.NS           1.117267
# BAJFINANCE.NS    2.056147
# APLAPOLLO.NS     1.321179
# PAGEIND.NS       0.876566
# DMART.NS         0.524289
# ALKYLAMINE.NS    1.128341
# VBL.NS           1.142092
# TITAN.NS         1.046903
# BHARTIARTL.NS    0.603638
# EICHERMOT.NS     0.907913
# CDSL.NS          0.801445
# KEI.NS           1.772438
# JUBLFOOD.NS      0.907220
# ASTRAL.NS        0.897332
# GOLDBEES.NS     -0.024010
# dtype: float64
#
# ------r squared scores------
# HDFC.NS          0.683384
# NIFTYBEES.NS     0.997939
# SUNPHARMA.NS     0.177038
# TATAMOTORS.NS    0.414757
# ASIANPAINT.NS    0.202430
# NESTLEIND.NS     0.086266
# TCS.NS           0.210532
# PVR.NS           0.262161
# BAJFINANCE.NS    0.644750
# APLAPOLLO.NS     0.363288
# PAGEIND.NS       0.273449
# ...

# %% [markdown]
# # Initializing risk free rate and finding market return

# %%
rm = log_returns["^NSEI"].mean() * 252
print("rm: "+str(rm))
rf=0.03
print("rf: "+str(rf))
# Out:
# rm: 2.2322017321063403
# rf: 0.03

# %% [markdown]
# # Calculating expected return, volatility and covariance of stocks

# %% [markdown]
# CAPM Model is used to calculate beta using expected return.

# %%
er_capm = rf+(beta_df*(rm-rf))
er_capm
#er_capm=er_capm.drop(labels='^NSEI')
#er_capm
# Out:
# HDFC.NS          2.520488
# NIFTYBEES.NS     2.184889
# SUNPHARMA.NS     1.408097
# TATAMOTORS.NS    4.257834
# ASIANPAINT.NS    1.280614
# NESTLEIND.NS     0.661176
# TCS.NS           1.251080
# PVR.NS           2.490448
# BAJFINANCE.NS    4.558051
# APLAPOLLO.NS     2.939502
# PAGEIND.NS       1.960376
# DMART.NS         1.184589
# ALKYLAMINE.NS    2.514836
# VBL.NS           2.545117
# TITAN.NS         2.335491
# BHARTIARTL.NS    1.359332
# EICHERMOT.NS     2.029408
# CDSL.NS          1.794944
# KEI.NS           3.933266
# JUBLFOOD.NS      2.027881
# ASTRAL.NS        2.006106
# GOLDBEES.NS     -0.022875
# dtype: float64

# %%
log_ret=log_returns.drop(columns="^NSEI")
cov=log_ret.cov()

# %% [markdown]
# # **CASE 1**
# no short selling, no riskless borrowing/lending

# %% [markdown]
# initializing number of random portfolios, utility function coefficients and other variables.

# %%
num_ports = 15000

Util=np.zeros(num_ports)   # Empty list to store utility function values
A=4                        # Risk Aversion factor
max_util_ret=0
max_util_risk=0

# %% [markdown]
# Using for loop to calculate returns and volatility of random weighted portfolios

# %%
np.random.seed(101)
num_ports = 15000
all_weights = np.zeros((num_ports,n))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)

for ind in range(num_ports):

    # Create Random Weights
    weights = np.array(np.random.random(n))

    # Rebalance Weights
    weights = weights / np.sum(weights)
    
    # Save Weights
    all_weights[ind,:] = weights

    # Expected Return
    ret_arr[ind] = np.sum(er_capm*weights)

    # Expected Variance
    vol_arr[ind] = np.sqrt(np.dot(weights.T, np.dot(cov * 252, weights)))

    # Sharpe Ratio
    sharpe_arr[ind] = (ret_arr[ind]-rf)/vol_arr[ind]
    
    #calculating utility values for this random portfolio's return and volatility
    Util[ind]=(ret_arr[ind]-0.5*A*vol_arr[ind]**2)
    if Util[ind]>=max(Util):
        max_util_ret=ret_arr[ind]
        max_util_risk=vol_arr[ind]

# %% [markdown]
# Finding MVP and Maximum Utility portfolio

# %%
# To find Minimum Variance and corresponding returns
min_vol_port = vol_arr.min()  
ind=np.argmin(vol_arr)  #index of minimum volitality

# %%
print("Maximum Utility function:",max(Util))
print("Return corresponding to Maximum Utility:",max_util_ret)
print("Risk corresponding to Maximum Utility:",max_util_risk)
# Out:
# Maximum Utility function: 1.1006450558768985
# Return corresponding to Maximum Utility: 2.3415038399470265
# Risk corresponding to Maximum Utility: 0.7876734044228382

# %%
risk=np.linspace(vol_arr.min(),vol_arr.max(),50)
print(risk)
# Out:
# [0.77402205 0.78366436 0.79330666 0.80294897 0.81259128 0.82223358
#  0.83187589 0.8415182  0.8511605  0.86080281 0.87044512 0.88008743
#  0.88972973 0.89937204 0.90901435 0.91865665 0.92829896 0.93794127
#  0.94758357 0.95722588 0.96686819 0.9765105  0.9861528  0.99579511
#  1.00543742 1.01507972 1.02472203 1.03436434 1.04400664 1.05364895
#  1.06329126 1.07293357 1.08257587 1.09221818 1.10186049 1.11150279
#  1.1211451  1.13078741 1.14042971 1.15007202 1.15971433 1.16935664
#  1.17899894 1.18864125 1.19828356 1.20792586 1.21756817 1.22721048
#  1.23685278 1.24649509]

# %%
exp_ret=max(Util)+0.5*4*risk**2
exp_ret
# Out:
# array([2.29886532, 2.3289047 , 2.35931598, 2.39009915, 2.42125422,
#        2.45278119, 2.48468005, 2.51695081, 2.54959346, 2.58260802,
#        2.61599446, 2.64975281, 2.68388305, 2.71838519, 2.75325922,
#        2.78850515, 2.82412298, 2.8601127 , 2.89647432, 2.93320783,
#        2.97031324, 3.00779055, 3.04563976, 3.08386086, 3.12245385,
#        3.16141875, 3.20075554, 3.24046422, 3.2805448 , 3.32099728,
#        3.36182166, 3.40301793, 3.4445861 , 3.48652616, 3.52883812,
#        3.57152198, 3.61457773, 3.65800538, 3.70180492, 3.74597637,
#        3.7905197 , 3.83543494, 3.88072207, 3.9263811 , 3.97241202,
#        4.01881484, 4.06558956, 4.11273617, 4.16025468, 4.20814508])

# %% [markdown]
# ### Plots

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr,ret_arr,marker = 'o' , s = 10 ,alpha = 0.5 , color = 'green' )
plt.plot(risk,exp_ret)
plt.scatter(max_util_risk,max_util_ret,color='r',s=200,marker='*')
plt.scatter(min_vol_port,ret_arr[ind],color='b',s=200)
plt.title("Efficient Frontier")
plt.xlabel('Volatility')
plt.ylabel('Return')
x_min=0.8
x_max=2 
y_min=1
y_max=3
plt.axis([x_min, x_max, y_min, y_max])
# Out:
# (0.8, 2.0, 1.0, 3.0)

# %% [markdown]
# #**CASE 2**
#
# With short selling allowed and riskless lending/borrowing

# %% [markdown]
# Negative weights are permitted for the short selling case.

# %%
num_ports = 15000
Util=np.zeros(num_ports)  # Empty list to store utility function values
A=4       # Risk Aversion factor
max_util_ret=0
max_util_risk=0

# %%
np.random.seed(101)
num_ports = 15000
all_weights = np.zeros((num_ports,n))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)
ind=0
while ind < num_ports :

    # Create Random Weights
    weights = np.array(np.random.randint(-5000,5000,n))

    if np.sum(weights)==0 :
          continue

    # Rebalance Weights
    weights = weights / np.sum(weights)
    
    # Save Weights
    all_weights[ind,:] = weights

    # Expected Return
    ret_arr[ind] = np.sum(er_capm*weights)

    # Expected Variance
    vol_arr[ind] = np.sqrt(np.dot(weights.T, np.dot(cov * 252, weights)))

    # Sharpe Ratio
    sharpe_arr[ind] = (ret_arr[ind]-rf)/vol_arr[ind]
    
    Util[ind]=ret_arr[ind]-0.5*A*vol_arr[ind]**2
    if Util[ind]>=max(Util):
        max_util_ret=ret_arr[ind]
        max_util_risk=vol_arr[ind]
    
    ind+=1

# %%
# To find Minimum Variance and corresponding returns
#ret_arr=ret_arr[np.logical_not(np.isnan(vol_arr))]
#Util=Util[np.logical_not(np.isnan(vol_arr))]
#vol_arr=vol_arr[np.logical_not(np.isnan(vol_arr))]
min_vol_port = vol_arr.min()  
ind=np.argmin(vol_arr)  #index of minimum volitality
vol_arr.min()
# Out:
# 0.6710944727819145

# %%
print("Maximum Utility function:",max(Util))
print("Return corresponding to Maximum Utility:",max_util_ret)
print("Risk corresponding to Maximum Utility:",max_util_risk)
# Out:
# Maximum Utility function: 2.6520180105872564
# Return corresponding to Maximum Utility: 4.33818109094361
# Risk corresponding to Maximum Utility: 0.9181947180082102

# %%
risk=np.linspace(vol_arr.min(),vol_arr.max(),50)
print(risk)
# Out:
# [6.71094473e-01 3.73167109e+02 7.45663123e+02 1.11815914e+03
#  1.49065515e+03 1.86315116e+03 2.23564718e+03 2.60814319e+03
#  2.98063921e+03 3.35313522e+03 3.72563123e+03 4.09812725e+03
#  4.47062326e+03 4.84311928e+03 5.21561529e+03 5.58811130e+03
#  5.96060732e+03 6.33310333e+03 6.70559935e+03 7.07809536e+03
#  7.45059138e+03 7.82308739e+03 8.19558340e+03 8.56807942e+03
#  8.94057543e+03 9.31307145e+03 9.68556746e+03 1.00580635e+04
#  1.04305595e+04 1.08030555e+04 1.11755515e+04 1.15480475e+04
#  1.19205435e+04 1.22930396e+04 1.26655356e+04 1.30380316e+04
#  1.34105276e+04 1.37830236e+04 1.41555196e+04 1.45280156e+04
#  1.49005117e+04 1.52730077e+04 1.56455037e+04 1.60179997e+04
#  1.63904957e+04 1.67629917e+04 1.71354877e+04 1.75079838e+04
#  1.78804798e+04 1.82529758e+04]

# %%
exp_ret=max(Util)+0.5*4*risk**2
exp_ret
# Out:
# array([3.55275359e+00, 2.78510034e+05, 1.11202964e+06, 2.50056236e+06,
#        4.44410821e+06, 6.94266718e+06, 9.99623927e+06, 1.36048245e+07,
#        1.77684228e+07, 2.24870343e+07, 2.77606588e+07, 3.35892965e+07,
#        3.99729474e+07, 4.69116113e+07, 5.44052884e+07, 6.24539786e+07,
#        7.10576819e+07, 8.02163983e+07, 8.99301279e+07, 1.00198871e+08,
#        1.11022626e+08, 1.22401395e+08, 1.34335177e+08, 1.46823972e+08,
#        1.59867781e+08, 1.73466602e+08, 1.87620437e+08, 2.02329284e+08,
#        2.17593145e+08, 2.33412019e+08, 2.49785906e+08, 2.66714806e+08,
#        2.84198719e+08, 3.02237646e+08, 3.20831585e+08, 3.39980538e+08,
#        3.59684504e+08, 3.79943483e+08, 4.00757475e+08, 4.22126480e+08,
#        4.44050498e+08, 4.66529529e+08, 4.89563574e+08, 5.13152631e+08,
#        5.37296702e+08, 5.61995786e+08, 5.87249883e+08, 6.13058993e+08,
#        6.39423116e+08, 6.66342252e+08])

# %% [markdown]
# Maximizing sharp ratio in order to find optimal portfolio

# %%
# Finding the optimal portfolio : Highest SHARPE RATIO
optimal_risky_port_max = sharpe_arr.max()
index_max_sharpe=np.argmax(sharpe_arr)
max_sharpe_exp_ret = ret_arr[index_max_sharpe]
max_sharpe_vol = vol_arr[index_max_sharpe]

# %%
slope=(max_sharpe_exp_ret-rf)/max_sharpe_vol
x_rf = np.linspace(0,vol_arr.max(),4)
y_rf = (slope)*x_rf+rf

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr,ret_arr,marker = 'o' , s = 10 ,alpha = 0.5 , color = 'green' )
plt.scatter(max_sharpe_vol,max_sharpe_exp_ret,color='#d62728',s=100)
plt.scatter(min_vol_port,ret_arr[ind],color='y',s=100)
plt.plot(x_rf, y_rf, '-r', label='lending-borrowing')
#plt.plot(risk,exp_ret)
plt.title("Efficient Frontier")
plt.xlabel('Volatility')
plt.ylabel('Return')
x_min=0
x_max=13 
y_min=0
y_max=20
plt.axis([x_min, x_max, y_min, y_max])
# Out:
# (0.0, 13.0, 0.0, 20.0)
